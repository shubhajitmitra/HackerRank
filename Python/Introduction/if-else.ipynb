# %% [markdown]
# # Weird Not weird
# - **Problem Class - Easy**

# %% [markdown]
# ![Screen%20Shot%202020-08-03%20at%201.53.06%20PM.png](attachment:Screen%20Shot%202020-08-03%20at%201.53.06%20PM.png)

# %%
import math
import os
import random
import re
import sys

if __name__ == '__main__':
    n = int(input().strip())
    if n%2!=0:
        print("Weird")
    elif n >20:
        print("Not Weird")
    elif n>=6 and n<=20:
        print("Weird")
    elif n>=2 and n<=5:
        print("Not Weird")
# Out:
# 4
# Not Weird
