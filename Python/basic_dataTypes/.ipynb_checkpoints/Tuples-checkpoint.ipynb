# %% [markdown]
# ![Screen%20Shot%202020-08-24%20at%204.04.39%20PM.png](attachment:Screen%20Shot%202020-08-24%20at%204.04.39%20PM.png)

# %%
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    tup = ()

    for x in integer_list:
        tup+=(x,)
    print(hash(tup))
# Out:
# 3
# 1 2 3
# 529344067295497451

# %% [markdown]
# # Tutorial

# %% [markdown]
# ![Screen%20Shot%202020-08-24%20at%204.05.37%20PM.png](attachment:Screen%20Shot%202020-08-24%20at%204.05.37%20PM.png)
