# %% [markdown]
# # Any or all!!
#    - **Problem Class - Easy**

# %% [markdown]
# ![Screen%20Shot%202020-08-03%20at%2011.19.45%20PM.png](attachment:Screen%20Shot%202020-08-03%20at%2011.19.45%20PM.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
if __name__== "__main__":
    N=int(input())
    n_l = input().split()
    print (all(int(num)>=0 for num in n_l) and any ([num==num[::-1] for num in n_l]))
# Out:
# 14
# 12 14 15 19
# False
