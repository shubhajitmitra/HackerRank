# %% [markdown]
# ![Screen%20Shot%202020-08-26%20at%207.36.42%20AM.png](attachment:Screen%20Shot%202020-08-26%20at%207.36.42%20AM.png)

# %%
def split_and_join(line):
    # write your code here
    split = line.split(" ")
    join = "-".join(split)
    return join

if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)
# Out:
# Shubhajit Mitra
# Shubhajit-Mitra
