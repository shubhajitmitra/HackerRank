# %% [markdown]
# ![Screen%20Shot%202020-08-26%20at%209.11.14%20AM.png](attachment:Screen%20Shot%202020-08-26%20at%209.11.14%20AM.png)

# %%
def print_full_name(a, b):
    a=first_name
    b=last_name
    print(f"Hello {a} {b}! You just delved into python.")

if __name__ == '__main__':
    first_name = input()
    last_name = input()
    print_full_name(first_name, last_name)
# Out:
# Shubhajit Mitra
# mitra
# Hello Shubhajit Mitra mitra! You just delved into python.
