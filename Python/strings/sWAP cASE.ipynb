# %% [markdown]
# ![Screen%20Shot%202020-08-25%20at%202.57.20%20PM.png](attachment:Screen%20Shot%202020-08-25%20at%202.57.20%20PM.png)

# %%
def swap_case(s):
     for l in s:
        swap_case = s.swapcase()
        return swap_case

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)
# Out:
# Shubhajit Mitra
# sHUBHAJIT mITRA
